# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fig, axes = plt.subplots(2, 2, sharey = True)

#axes[0, 0].sns.(['black men', 'white men'], [0.5 , 0.6])
#axes[0, 0].barplot(['black men', 'white men'], [0.5 , 0.6])

sns.barplot(['black men', 'white men'], [0.5 , 0.6], color =[0.2, 0.4], ax=axes[0,0])
sns.barplot(['black men', 'black women'], [0.5 , 0.6], color =['window blue', 'pink'], ax=axes[0,1])
sns.barplot(['white men', 'white women'], [0.5 , 0.6], color =['orange', 'yellow'], ax=axes[1,0])
sns.barplot(['white women', 'black women'], [0.5 , 0.6], color =['yellow', 'pink'], ax=axes[1,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a41d17519701> in <module>()
#       5 #axes[0, 0].barplot(['black men', 'white men'], [0.5 , 0.6])
#       6
# ----> 7 sns.barplot(['black men', 'white men'], [0.5 , 0.6], color =[0.2, 0.4], ax=axes[0,0])
#       8 sns.barplot(['black men', 'black women'], [0.5 , 0.6], color =['window blue', 'pink'], ax=axes[0,1])
# ...
